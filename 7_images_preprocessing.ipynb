# %%
import os, duckdb, csv, random
import pandas as pd
from concurrent.futures import ThreadPoolExecutor, as_completed
from PIL import Image, ImageOps, ImageFile
from pprint import pprint

# %%
# Configuration and connection
DB_PATH = r"D:/db/meta.duckdb"                 

con = duckdb.connect(DB_PATH)

con.execute("PRAGMA threads=2;") 
con.execute("SET memory_limit='5GB';") 
con.execute("SET preserve_insertion_order=false;") 

print("\n Set up ready")
# Out:
#  Set up ready

# %%
# Exctract all images filenames

root = "D:/IMAGES/posts_image/image"
out  = "D:/images_filenames_all.csv"
exts = (".jpg", ".jpeg", ".png")
BATCH_SIZE = 100000

buffer = []
count  = 0

with open(out, "w", newline="", encoding="utf-8") as f:
    w = csv.writer(f)
    w.writerow(["filename"])  # intestazione

    for fn in os.listdir(root):
        if fn.lower().endswith(exts):
            buffer.append([fn])
            count += 1

            if len(buffer) >= BATCH_SIZE:
                w.writerows(buffer)
                buffer.clear()
                print(f"[progress] salvati {count:,d} file...")

    # flush finale
    if buffer:
        w.writerows(buffer)
        buffer.clear()

print(f"End! Total saved files: {count:,d}")
# Out:
# [progress] salvati 100,000 file...
# [progress] salvati 200,000 file...
# [progress] salvati 300,000 file...
# [progress] salvati 400,000 file...
# [progress] salvati 500,000 file...
# [progress] salvati 600,000 file...
# [progress] salvati 700,000 file...
# [progress] salvati 800,000 file...
# [progress] salvati 900,000 file...
# [progress] salvati 1,000,000 file...
# [progress] salvati 1,100,000 file...
# [progress] salvati 1,200,000 file...
# [progress] salvati 1,300,000 file...
# [progress] salvati 1,400,000 file...
# [progress] salvati 1,500,000 file...
# [progress] salvati 1,600,000 file...
# [progress] salvati 1,700,000 file...
# [progress] salvati 1,800,000 file...
# [progress] salvati 1,900,000 file...
# [progress] salvati 2,000,000 file...
# [progress] salvati 2,100,000 file...
# [progress] salvati 2,200,000 file...
# [progress] salvati 2,300,000 file...
# [progress] salvati 2,400,000 file...
# [progress] salvati 2,500,000 file...
# [progress] salvati 2,600,000 file...
# [progress] salvati 2,700,000 file...
# [progress] salvati 2,800,000 file...
# [progress] salvati 2,900,000 file...
# [progress] salvati 3,000,000 file...
# [progress] salvati 3,100,000 file...
# [progress] salvati 3,200,000 file...
# [progress] salvati 3,300,000 file...
# [progress] salvati 3,400,000 file...
# [progress] salvati 3,500,000 file...
# [progress] salvati 3,600,000 file...
# [progress] salvati 3,700,000 file...
# [progress] salvati 3,800,000 file...
# [progress] salvati 3,900,000 file...
# [progress] salvati 4,000,000 file...
# [progress] salvati 4,100,000 file...
# [progress] salvati 4,200,000 file...
# [progress] salvati 4,300,000 file...
# [progress] salvati 4,400,000 file...
# [progress] salvati 4,500,000 file...
# [progress] salvati 4,600,000 file...
# [progress] salvati 4,700,000 file...
# [progress] salvati 4,800,000 file...
# [progress] salvati 4,900,000 file...
# [progress] salvati 5,000,000 file...
# [progress] salvati 5,100,000 file...
# [progress] salvati 5,200,000 file...
# [progress] salvati 5,300,000 file...
# [progress] salvati 5,400,000 file...
# [progress] salvati 5,500,000 file...
# [progress] salvati 5,600,000 file...
# [progress] salvati 5,700,000 file...
# [progress] salvati 5,800,000 file...
# [progress] salvati 5,900,000 file...
# [progress] salvati 6,000,000 file...
# [progress] salvati 6,100,000 file...
# [progress] salvati 6,200,000 file...
# [progress] salvati 6,300,000 file...
# [progress] salvati 6,400,000 file...
# [progress] salvati 6,500,000 file...
# [progress] salvati 6,600,000 file...
# [progress] salvati 6,700,000 file...
# [progress] salvati 6,800,000 file...
# [progress] salvati 6,900,000 file...
# [progress] salvati 7,000,000 file...
# [progress] salvati 7,100,000 file...
# [progress] salvati 7,200,000 file...
# [progress] salvati 7,300,000 file...
# [progress] salvati 7,400,000 file...
# [progress] salvati 7,500,000 file...
# [progress] salvati 7,600,000 file...
# [progress] salvati 7,700,000 file...
# [progress] salvati 7,800,000 file...
# [progress] salvati 7,900,000 file...
# [progress] salvati 8,000,000 file...
# [progress] salvati 8,100,000 file...
# [progress] salvati 8,200,000 file...
# [progress] salvati 8,300,000 file...
# [progress] salvati 8,400,000 file...
# [progress] salvati 8,500,000 file...
# [progress] salvati 8,600,000 file...
# [progress] salvati 8,700,000 file...
# [progress] salvati 8,800,000 file...
# [progress] salvati 8,900,000 file...
# [progress] salvati 9,000,000 file...
# [progress] salvati 9,100,000 file...
# [progress] salvati 9,200,000 file...
# [progress] salvati 9,300,000 file...
# [progress] salvati 9,400,000 file...
# [progress] salvati 9,500,000 file...
# [progress] salvati 9,600,000 file...
# [progress] salvati 9,700,000 file...
# [progress] salvati 9,800,000 file...
# [progress] salvati 9,900,000 file...
# [progress] salvati 10,000,000 file...
# [progress] salvati 10,100,000 file...
# [progress] salvati 10,200,000 file...
# [progress] salvati 10,300,000 file...
# [progress] salvati 10,400,000 file...
# [progress] salvati 10,500,000 file...
# [progress] salvati 10,600,000 file...
# [progress] salvati 10,700,000 file...
# [progress] salvati 10,800,000 file...
# [progress] salvati 10,900,000 file...
# [progress] salvati 11,000,000 file...
# [progress] salvati 11,100,000 file...
# [progress] salvati 11,200,000 file...
# [progress] salvati 11,300,000 file...
# [progress] salvati 11,400,000 file...
# [progress] salvati 11,500,000 file...
# [progress] salvati 11,600,000 file...
# [progress] salvati 11,700,000 file...
# [progress] salvati 11,800,000 file...
# [progress] salvati 11,900,000 file...
# [progress] salvati 12,000,000 file...
# [progress] salvati 12,100,000 file...
# [progress] salvati 12,200,000 file...
# [progress] salvati 12,300,000 file...
# [progress] salvati 12,400,000 file...
# [progress] salvati 12,500,000 file...
# [progress] salvati 12,600,000 file...
# [progress] salvati 12,700,000 file...
# [progress] salvati 12,800,000 file...
# [progress] salvati 12,900,000 file...
# End! Total saved files: 12,933,406

# %%
con.execute("""CREATE OR REPLACE VIEW all_image_files AS
SELECT * 
FROM "D:/images_filenames_all.csv"
""")

# %%
# There are NO duplicate files in the image folder
print(con.sql("""
SELECT COUNT(*) AS total_images, COUNT(DISTINCT filename) AS distinct_files, COUNT(*) - COUNT(DISTINCT filename) AS duplicates 
FROM all_image_files
"""))
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# ┌──────────────┬────────────────┬────────────┐
# │ total_images │ distinct_files │ duplicates │
# │    int64     │     int64      │   int64    │
# ├──────────────┼────────────────┼────────────┤
# │     12933406 │       12933406 │          0 │
# └──────────────┴────────────────┴────────────┘

# %%
# In the manifest but not in the folder
print(con.sql("""
SELECT 
    COUNT(*) AS total_in_manifest,
    SUM(CASE WHEN f.filename IS NULL THEN 1 ELSE 0 END) AS not_in_folder,
    SUM(CASE WHEN f.filename IS NOT NULL THEN 1 ELSE 0 END) AS found_in_folder
FROM images_manifest AS m
LEFT JOIN all_image_files AS f
    ON m.full_image_file = f.filename;
"""))
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# ┌───────────────────┬───────────────┬─────────────────┐
# │ total_in_manifest │ not_in_folder │ found_in_folder │
# │       int64       │    int128     │     int128      │
# ├───────────────────┼───────────────┼─────────────────┤
# │          12788311 │         12577 │        12775734 │
# └───────────────────┴───────────────┴─────────────────┘

# %%
# In the manifest but not in the folder 17-18
print(con.sql("""
SELECT 
    COUNT(*) AS total_in_manifest,
    SUM(CASE WHEN f.filename IS NULL THEN 1 ELSE 0 END) AS not_in_folder,
    SUM(CASE WHEN f.filename IS NOT NULL THEN 1 ELSE 0 END) AS found_in_folder
FROM images_manifest1718 AS m
LEFT JOIN all_image_files AS f
    ON m.full_image_file = f.filename;
"""))
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# ┌───────────────────┬───────────────┬─────────────────┐
# │ total_in_manifest │ not_in_folder │ found_in_folder │
# │       int64       │    int128     │     int128      │
# ├───────────────────┼───────────────┼─────────────────┤
# │           8666392 │          1971 │         8664421 │
# └───────────────────┴───────────────┴─────────────────┘

# %%
# In the folder but not in the manifest
print(con.sql("""
SELECT 
    COUNT(*) AS total_in_folder,
    SUM(CASE WHEN m.full_image_file IS NULL THEN 1 ELSE 0 END) AS not_in_manifest,
    SUM(CASE WHEN m.full_image_file IS NOT NULL THEN 1 ELSE 0 END) AS found_in_manifest
FROM all_image_files AS f
LEFT JOIN images_manifest AS m
    ON f.filename = m.full_image_file;
"""))
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# ┌─────────────────┬─────────────────┬───────────────────┐
# │ total_in_folder │ not_in_manifest │ found_in_manifest │
# │      int64      │     int128      │      int128       │
# ├─────────────────┼─────────────────┼───────────────────┤
# │        12933406 │          157672 │          12775734 │
# └─────────────────┴─────────────────┴───────────────────┘

# %%
# Manifest ready removing the rows without matching image in the folder
con.execute("""
CREATE OR REPLACE TABLE images_manifest_clean AS
SELECT m.*
FROM images_manifest AS m
INNER JOIN all_image_files AS f
    ON m.full_image_file = f.filename;
""")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
print(con.sql("""SELECT COUNT(*) AS images FROM images_manifest_clean"""))
# Out:
# ┌──────────┐
# │  images  │
# │  int64   │
# ├──────────┤
# │ 12775734 │
# └──────────┘

# %%
# Same but for 17-18
con.execute("""
CREATE OR REPLACE TABLE images_manifest1718_clean AS
SELECT m.*
FROM images_manifest1718 AS m
INNER JOIN all_image_files AS f
    ON m.full_image_file = f.filename;
""")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
print(con.sql("""SELECT COUNT(*) AS images FROM images_manifest1718_clean"""))
# Out:
# ┌─────────┐
# │ images  │
# │  int64  │
# ├─────────┤
# │ 8664413 │
# └─────────┘

# %%
ImageFile.LOAD_TRUNCATED_IMAGES = True

DB_PATH       = "D:/db/meta.duckdb"
RAW_IMG_ROOT  = "D:/IMAGES/posts_image"
CLEAN_IMG_DIR = "D:/dataset/images_224_rgb"
os.makedirs(CLEAN_IMG_DIR, exist_ok=True)

TARGET_SIZE = (224, 224)
JPEG_KW = dict(quality=85, subsampling=2, optimize=True, progressive=True)
MAX_WORKERS = max(4, os.cpu_count() * 2)
BATCH_SIZE  = 100_000

def src_path(t): return os.path.join(RAW_IMG_ROOT, "image", t.strip())
def dst_path(t): return os.path.join(CLEAN_IMG_DIR, t.strip())

def process_one(t):
    src = src_path(t); dst = dst_path(t); tmp = dst + ".part"
    try:
        if os.path.exists(dst):     return None # already in the destination folder
        if not os.path.exists(src): return "missing" # not in the source folder
        os.makedirs(os.path.dirname(dst), exist_ok=True)

        with Image.open(src) as img:
            img = ImageOps.exif_transpose(img).convert("RGB")
            img = ImageOps.fit(img, TARGET_SIZE, method=Image.Resampling.LANCZOS) 
            img.save(tmp, "JPEG", **JPEG_KW)
        os.replace(tmp, dst)
        return "ok"
    except Exception:
        try:
            if os.path.exists(tmp): os.remove(tmp)
        except: pass
        return "error"

# %%
# PREPROCESSING
con = duckdb.connect(DB_PATH)
total = con.sql("SELECT COUNT(*) FROM images_manifest1718_clean").fetchone()[0]
ok_count = miss_count = err_count = offset = 0

while offset < total:
    rows = [r[0] for r in con.sql(
        f"SELECT full_image_file FROM images_manifest1718_clean "
        f"LIMIT {BATCH_SIZE} OFFSET {offset}"
    ).fetchall()]

    rows = [t for t in rows if not os.path.exists(dst_path(t))]
    if not rows:
        offset += BATCH_SIZE
        continue

    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as ex:
        for res in ex.map(process_one, rows, chunksize=64):
            if res == "ok": ok_count += 1
            elif res == "missing": miss_count += 1
            elif res == "error": err_count += 1

    print(f"[BATCH offset={offset:,}] ok={ok_count:,} missing={miss_count:,} error={err_count:,}")
    offset += BATCH_SIZE

con.close()
print("\n[FINITO] Totale immagini preprocessate:", ok_count)
# Out:
# [BATCH offset=0] ok=100,000 missing=0 error=0
# [BATCH offset=100,000] ok=200,000 missing=0 error=0
# [BATCH offset=200,000] ok=300,000 missing=0 error=0
# [BATCH offset=300,000] ok=400,000 missing=0 error=0
# [BATCH offset=400,000] ok=500,000 missing=0 error=0
# [BATCH offset=500,000] ok=600,000 missing=0 error=0
# [BATCH offset=600,000] ok=700,000 missing=0 error=0
# [BATCH offset=700,000] ok=800,000 missing=0 error=0
# [BATCH offset=800,000] ok=900,000 missing=0 error=0
# [BATCH offset=900,000] ok=1,000,000 missing=0 error=0
# [BATCH offset=1,000,000] ok=1,100,000 missing=0 error=0
# [BATCH offset=1,100,000] ok=1,200,000 missing=0 error=0
# [BATCH offset=1,200,000] ok=1,300,000 missing=0 error=0
# [BATCH offset=1,300,000] ok=1,400,000 missing=0 error=0
# [BATCH offset=1,400,000] ok=1,500,000 missing=0 error=0
# [BATCH offset=1,500,000] ok=1,600,000 missing=0 error=0
# [BATCH offset=1,600,000] ok=1,700,000 missing=0 error=0
# [BATCH offset=1,700,000] ok=1,800,000 missing=0 error=0
# [BATCH offset=1,800,000] ok=1,900,000 missing=0 error=0
# [BATCH offset=1,900,000] ok=2,000,000 missing=0 error=0
# [BATCH offset=2,000,000] ok=2,100,000 missing=0 error=0
# [BATCH offset=2,100,000] ok=2,200,000 missing=0 error=0
# [BATCH offset=2,200,000] ok=2,300,000 missing=0 error=0
# [BATCH offset=2,300,000] ok=2,400,000 missing=0 error=0
# [BATCH offset=2,400,000] ok=2,500,000 missing=0 error=0
# [BATCH offset=2,500,000] ok=2,600,000 missing=0 error=0
# [BATCH offset=2,600,000] ok=2,700,000 missing=0 error=0
# [BATCH offset=2,700,000] ok=2,800,000 missing=0 error=0
# [BATCH offset=2,800,000] ok=2,900,000 missing=0 error=0
# [BATCH offset=2,900,000] ok=3,000,000 missing=0 error=0
# [BATCH offset=3,000,000] ok=3,100,000 missing=0 error=0
# [BATCH offset=3,100,000] ok=3,200,000 missing=0 error=0
# [BATCH offset=3,200,000] ok=3,300,000 missing=0 error=0
# [BATCH offset=3,300,000] ok=3,400,000 missing=0 error=0
# [BATCH offset=3,400,000] ok=3,500,000 missing=0 error=0
# [BATCH offset=3,500,000] ok=3,600,000 missing=0 error=0
# [BATCH offset=3,600,000] ok=3,700,000 missing=0 error=0
# [BATCH offset=3,700,000] ok=3,800,000 missing=0 error=0
# [BATCH offset=3,800,000] ok=3,900,000 missing=0 error=0
# [BATCH offset=3,900,000] ok=4,000,000 missing=0 error=0
# [BATCH offset=4,000,000] ok=4,100,000 missing=0 error=0
# [BATCH offset=4,100,000] ok=4,200,000 missing=0 error=0
# [BATCH offset=4,200,000] ok=4,300,000 missing=0 error=0
# [BATCH offset=4,300,000] ok=4,400,000 missing=0 error=0
# [BATCH offset=4,400,000] ok=4,500,000 missing=0 error=0
# [BATCH offset=4,500,000] ok=4,600,000 missing=0 error=0
# [BATCH offset=4,600,000] ok=4,700,000 missing=0 error=0
# [BATCH offset=4,700,000] ok=4,800,000 missing=0 error=0
# [BATCH offset=4,800,000] ok=4,900,000 missing=0 error=0
# [BATCH offset=4,900,000] ok=5,000,000 missing=0 error=0
# [BATCH offset=5,000,000] ok=5,100,000 missing=0 error=0
# [BATCH offset=5,100,000] ok=5,200,000 missing=0 error=0
# [BATCH offset=5,200,000] ok=5,300,000 missing=0 error=0
# [BATCH offset=5,300,000] ok=5,400,000 missing=0 error=0
# [BATCH offset=5,400,000] ok=5,500,000 missing=0 error=0
# [BATCH offset=5,500,000] ok=5,600,000 missing=0 error=0
# [BATCH offset=5,600,000] ok=5,700,000 missing=0 error=0
# [BATCH offset=5,700,000] ok=5,800,000 missing=0 error=0
# [BATCH offset=5,800,000] ok=5,900,000 missing=0 error=0
# [BATCH offset=5,900,000] ok=6,000,000 missing=0 error=0
# [BATCH offset=6,000,000] ok=6,100,000 missing=0 error=0
# [BATCH offset=6,100,000] ok=6,200,000 missing=0 error=0
# [BATCH offset=6,200,000] ok=6,300,000 missing=0 error=0
# [BATCH offset=6,300,000] ok=6,400,000 missing=0 error=0
# [BATCH offset=6,400,000] ok=6,500,000 missing=0 error=0
# [BATCH offset=6,500,000] ok=6,600,000 missing=0 error=0
# [BATCH offset=6,600,000] ok=6,700,000 missing=0 error=0

# %%
# Exctract the clean images filenames

root = "D:/dataset/images_224_rgb"
out  = "D:/clean_filenames.csv"
exts = (".jpg", ".jpeg", ".png")
BATCH_SIZE = 100000

buffer = []
count  = 0

with open(out, "w", newline="", encoding="utf-8") as f:
    w = csv.writer(f)
    w.writerow(["filename"])

    for fn in os.listdir(root):
        if fn.lower().endswith(exts):
            buffer.append([fn])
            count += 1

            if len(buffer) >= BATCH_SIZE:
                w.writerows(buffer)
                buffer.clear()
                print(f"[progress] salvati {count:,d} file...")

    if buffer:
        w.writerows(buffer)
        buffer.clear()

print(f"End! Total saved files: {count:,d}")
# Out:
# [progress] salvati 100,000 file...
# [progress] salvati 200,000 file...
# [progress] salvati 300,000 file...
# [progress] salvati 400,000 file...
# [progress] salvati 500,000 file...
# [progress] salvati 600,000 file...
# [progress] salvati 700,000 file...
# [progress] salvati 800,000 file...
# [progress] salvati 900,000 file...
# [progress] salvati 1,000,000 file...
# [progress] salvati 1,100,000 file...
# [progress] salvati 1,200,000 file...
# [progress] salvati 1,300,000 file...
# [progress] salvati 1,400,000 file...
# [progress] salvati 1,500,000 file...
# [progress] salvati 1,600,000 file...
# [progress] salvati 1,700,000 file...
# [progress] salvati 1,800,000 file...
# [progress] salvati 1,900,000 file...
# [progress] salvati 2,000,000 file...
# [progress] salvati 2,100,000 file...
# [progress] salvati 2,200,000 file...
# [progress] salvati 2,300,000 file...
# [progress] salvati 2,400,000 file...
# [progress] salvati 2,500,000 file...
# [progress] salvati 2,600,000 file...
# [progress] salvati 2,700,000 file...
# [progress] salvati 2,800,000 file...
# [progress] salvati 2,900,000 file...
# [progress] salvati 3,000,000 file...
# [progress] salvati 3,100,000 file...
# [progress] salvati 3,200,000 file...
# [progress] salvati 3,300,000 file...
# [progress] salvati 3,400,000 file...
# [progress] salvati 3,500,000 file...
# [progress] salvati 3,600,000 file...
# [progress] salvati 3,700,000 file...
# [progress] salvati 3,800,000 file...
# [progress] salvati 3,900,000 file...
# [progress] salvati 4,000,000 file...
# [progress] salvati 4,100,000 file...
# [progress] salvati 4,200,000 file...
# [progress] salvati 4,300,000 file...
# [progress] salvati 4,400,000 file...
# [progress] salvati 4,500,000 file...
# [progress] salvati 4,600,000 file...
# [progress] salvati 4,700,000 file...
# [progress] salvati 4,800,000 file...
# [progress] salvati 4,900,000 file...
# [progress] salvati 5,000,000 file...
# [progress] salvati 5,100,000 file...
# [progress] salvati 5,200,000 file...
# [progress] salvati 5,300,000 file...
# [progress] salvati 5,400,000 file...
# [progress] salvati 5,500,000 file...
# [progress] salvati 5,600,000 file...
# [progress] salvati 5,700,000 file...
# [progress] salvati 5,800,000 file...
# [progress] salvati 5,900,000 file...
# [progress] salvati 6,000,000 file...
# [progress] salvati 6,100,000 file...
# [progress] salvati 6,200,000 file...
# [progress] salvati 6,300,000 file...
# [progress] salvati 6,400,000 file...
# [progress] salvati 6,500,000 file...
# [progress] salvati 6,600,000 file...
# [progress] salvati 6,700,000 file...
# [progress] salvati 6,800,000 file...
# [progress] salvati 6,900,000 file...
# [progress] salvati 7,000,000 file...
# [progress] salvati 7,100,000 file...
# [progress] salvati 7,200,000 file...
# [progress] salvati 7,300,000 file...
# [progress] salvati 7,400,000 file...
# [progress] salvati 7,500,000 file...
# [progress] salvati 7,600,000 file...
# [progress] salvati 7,700,000 file...
# [progress] salvati 7,800,000 file...
# [progress] salvati 7,900,000 file...
# [progress] salvati 8,000,000 file...
# [progress] salvati 8,100,000 file...
# [progress] salvati 8,200,000 file...
# [progress] salvati 8,300,000 file...
# [progress] salvati 8,400,000 file...
# [progress] salvati 8,500,000 file...
# [progress] salvati 8,600,000 file...
# End! Total saved files: 8,664,413

# %%
con.execute("""
CREATE OR REPLACE TABLE clean_files AS
SELECT * FROM "D:/clean_filenames.csv"
""")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
# CHECK
print(con.sql("""SELECT COUNT(*) AS rows_manifest FROM images_manifest1718_clean"""))
print(con.sql("""SELECT COUNT(*) AS rows_cleaned FROM clean_files"""))
# Out:
# ┌───────────────┐
# │ rows_manifest │
# │     int64     │
# ├───────────────┤
# │       8664413 │
# └───────────────┘
#
# ┌──────────────┐
# │ rows_cleaned │
# │    int64     │
# ├──────────────┤
# │      8664413 │
# └──────────────┘

# %%
# Check the changes have been made
DB_PATH       = r"D:/db/meta.duckdb"
RAW_IMG_ROOT  = r"D:/IMAGES/posts_image"
SRC_SUBDIR    = "image"
OUT_DIR       = r"D:/dataset/images_224_rgb"

def src_path(t): return os.path.join(RAW_IMG_ROOT, SRC_SUBDIR, t.strip())
def dst_path(t): return os.path.join(OUT_DIR, t.strip())

con = duckdb.connect(DB_PATH)
targets = [r[0] for r in con.sql("SELECT full_image_file FROM images_manifest1718_clean LIMIT 2000").fetchall()]
con.close()

both_exist = [t for t in targets if os.path.exists(src_path(t)) and os.path.exists(dst_path(t))]
sample = random.sample(both_exist, min(10, len(both_exist)))

report = []
for t in sample:
    with Image.open(src_path(t)) as im_src, Image.open(dst_path(t)) as im_dst:
        report.append({
            "target_name": t,
            "src_format": im_src.format, "src_mode": im_src.mode, "src_size": im_src.size,
            "dst_format": im_dst.format, "dst_mode": im_dst.mode, "dst_size": im_dst.size,
        })

pprint(report)
# Out:
# [{'dst_format': 'JPEG',
#   'dst_mode': 'RGB',
#   'dst_size': (224, 224),
#   'src_format': 'JPEG',
#   'src_mode': 'RGB',
#   'src_size': (256, 320),
#   'target_name': 'aforteforfashion-1856117939247008270.jpg'},
#  {'dst_format': 'JPEG',
#   'dst_mode': 'RGB',
#   'dst_size': (224, 224),
#   'src_format': 'JPEG',
#   'src_mode': 'RGB',
#   'src_size': (256, 321),
#   'target_name': 'afromamanyc-1549686774297503403.jpg'},
#  {'dst_format': 'JPEG',
#   'dst_mode': 'RGB',
#   'dst_size': (224, 224),
#   'src_format': 'JPEG',
#   'src_mode': 'RGB',
#   'src_size': (256, 306),
#   'target_name': 'africasblog-1662866696798687219.jpg'},
#  {'dst_format': 'JPEG',
#   'dst_mode': 'RGB',
#   'dst_size': (224, 224),
#   'src_format': 'JPEG',
#   'src_mode': 'RGB',
#   'src_size': (256, 320),
#   'target_name': 'afreen_rahman-1763264467610670797.jpg'},
#  {'dst_format': 'JPEG',
#   'dst_mode': 'RGB',
#   'dst_size': (224, 224),
#   'src_format': 'JPEG',
#   'src_mode': 'RGB',
#   'src_size': (256, 256),
#   'target_name': 'africasblog-1818517615807802793.jpg'},
#  {'dst_format': 'JPEG',
#   'dst_mode': 'RGB',
#   'dst_size': (224, 224),
#   'src_format': 'JPEG',
#   'src_mode': 'RGB',
#   'src_size': (256, 304),
#   'target_name': 'afreen_rahman-1764147750569644260.jpg'},
#  {'dst_format': 'JPEG',
#   'dst_mode': 'RGB',
#   'dst_size': (224, 224),
#   'src_format': 'JPEG',
#   'src_mode': 'RGB',
#   'src_size': (342, 256),
#   'target_name': 'afromamanyc-1682767027604688945.jpg'},
#  {'dst_format': 'JPEG',
#   'dst_mode': 'RGB',
#   'dst_size': (224, 224),
#   'src_format': 'JPEG',
#   'src_mode': 'RGB',
#   'src_size': (256, 320),
#   'target_name': 'aforeverlylove-1808776290711704637.jpg'},
#  {'dst_format': 'JPEG',
#   'dst_mode': 'RGB',
#   'dst_size': (224, 224),
#   'src_format': 'JPEG',
#   'src_mode': 'RGB',
#   'src_size': (256, 320),
#   'target_name': 'afreen_rahman-1729105937490197965.jpg'},
#  {'dst_format': 'JPEG',
#   'dst_mode': 'RGB',
#   'dst_size': (224, 224),
#   'src_format': 'JPEG',
#   'src_mode': 'RGB',
#   'src_size': (256, 320),
#   'target_name': 'afreen_rahman-1918509761295207998.jpg'}]

# %%
con.sql("""SELECT * FROM information_schema.tables """).fetchdf()
# Out:
#    table_catalog table_schema                 table_name  table_type  \
# 0           meta         main                clean_files  BASE TABLE
# 1           meta         main      design_train_balanced  BASE TABLE
# 2           meta         main            images_manifest  BASE TABLE
# 3           meta         main        images_manifest1718  BASE TABLE
# 4           meta         main  images_manifest1718_clean  BASE TABLE
# 5           meta         main      images_manifest_clean  BASE TABLE
# 6           meta         main               img_to_train  BASE TABLE
# 7           meta         main                influencers  BASE TABLE
# 8           meta         main                   metadata  BASE TABLE
# 9           meta         main               metadata1718  BASE TABLE
# 10          meta         main        metadata1718_hasimg  BASE TABLE
# 11          meta         main                   to_check  BASE TABLE
# 12          meta         main             train_balanced  BASE TABLE
# 13          meta         main       train_users_balanced  BASE TABLE
# 14          meta         main            all_image_files        VIEW
# 15          meta         main               design_table        VIEW
# 16          meta         main                design_test        VIEW
# 17          meta         main                 design_val        VIEW
# 18          meta         main               images_train        VIEW
# 19          meta         main               sample_month        VIEW
# 20          meta         main              to_preprocess        VIEW
# 21          meta         main              v_influencers        VIEW
# 22          meta         main               v_metadata_1        VIEW
# 23          meta         main             v_metadata_raw        VIEW
# 24          meta         main          v_meta_after_join        VIEW
# 25          meta         main         v_meta_before_join        VIEW
#
#    self_referencing_column_name reference_generation  \
# 0                          None                 None
# 1                          None                 None
# 2                          None                 None
# 3                          None                 None
# 4                          None                 None
# 5                          None                 None
# 6                          None                 None
# 7                          None                 None
# 8                          None                 None
# 9                          None                 None
# 10                         None                 None
# 11                         None                 None
# 12                         None                 None
# 13                         None                 None
# 14                         None                 None
# 15                         None                 None
# 16                         None                 None
# 17                         None                 None
# 18                         None                 None
# 19                         None                 None
# 20                         None                 None
# 21                         None                 None
# 22                         None                 None
# 23                         None                 None
# 24                         None                 None
# 25                         None                 None
#
#    user_defined_type_catalog user_defined_type_schema user_defined_type_name  \
# 0                       None                     None                   None
# 1                       None                     None                   None
# 2                       None                     None                   None
# 3                       None                     None                   None
# 4                       None                     None                   None
# 5                       None                     None                   None
# 6                       None                     None                   None
# 7                       None                     None                   None
# 8                       None                     None                   None
# 9                       None                     None                   None
# 10                      None                     None                   None
# 11                      None                     None                   None
# 12                      None                     None                   None
# 13                      None                     None                   None
# 14                      None                     None                   None
# 15                      None                     None                   None
# 16                      None                     None                   None
# 17                      None                     None                   None
# 18                      None                     None                   None
# 19                      None                     None                   None
# 20                      None                     None                   None
# 21                      None                     None                   None
# 22                      None                     None                   None
# 23                      None                     None                   None
# 24                      None                     None                   None
# 25                      None                     None                   None
#
#    is_insertable_into is_typed commit_action TABLE_COMMENT
# 0                 YES       NO          None          None
# 1                 YES       NO          None          None
# 2                 YES       NO          None          None
# 3                 YES       NO          None          None
# 4                 YES       NO          None          None
# 5                 YES       NO          None          None
# 6                 YES       NO          None          None
# 7                 YES       NO          None          None
# 8                 YES       NO          None          None
# 9                 YES       NO          None          None
# 10                YES       NO          None          None
# 11                YES       NO          None          None
# 12                YES       NO          None          None
# 13                YES       NO          None          None
# 14                 NO       NO          None          None
# 15                 NO       NO          None          None
# 16                 NO       NO          None          None
# 17                 NO       NO          None          None
# 18                 NO       NO          None          None
# 19                 NO       NO          None          None
# 20                 NO       NO          None          None
# 21                 NO       NO          None          None
# 22                 NO       NO          None          None
# 23                 NO       NO          None          None
# 24                 NO       NO          None          None
# 25                 NO       NO          None          None

# %%
con.close()
